# %%
import pandas as pd
import matplotlib.pyplot as plt
import wordcloud
from palettable.colorbrewer.sequential import Greens_9
from collections import defaultdict
from nltk import ngrams
from palettable.colorbrewer.sequential import Reds_9
import numpy as np
import csv
import random
from PIL import Image
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn import preprocessing
import seaborn as sns
import jieba

# %%
def color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Greens_9.colors[random.randint(2,8)])

import json
with open("data/pos_tfidf.JSON", 'r') as fp:
    pos_text = json.load( fp)
    

with open("data/neg_tfidf.JSON", 'r') as fp:
    neg_text = json.load( fp)




words_array = []

textneg = ' '.join(str(x) for x in neg_text)
textpos = ' '.join(str(x) for x in pos_text)

# %%
def wrodfreq(art):
    
    art = re.sub(r, '', art)
    art = re.sub("[a-z]","",art)
    
    return word_lst

# %%
a = wrodfreq(textneg)

# %%
import pandas as pd
sort_imp = pd.read_csv("result/sort_importance.csv")

# %%
sort_imp
# Out:
#         name  importance
# 0         买入    0.053504
# 1         中性    0.031126
# 2         下降    0.013671
# 3         营业    0.012202
# 4         收入    0.010727
# 5        eps    0.009887
# 6        毛利率    0.009847
# 7        百分点    0.009381
# 8         同比    0.009136
# 9         下调    0.008752
# 10        预计    0.008435
# 11        评级    0.008173
# 12        对应    0.007765
# 13        财务    0.007397
# 14        风险    0.006940
# 15        归母    0.006306
# 16       上半年    0.006150
# 17        下滑    0.006092
# 18       费用率    0.005917
# 19        事件    0.005862
# 20        预测    0.005849
# 21        亿元    0.005773
# 22       净利润    0.005699
# 23        公司    0.005685
# 24        预期    0.005443
# 25       归属于    0.005257
# 26        分别    0.005094
# 27        实现    0.004776
# 28        行业    0.004656
# 29        持续    0.004562
# ...      ...         ...
# 17752     基站    0.000000
# 17753     基拟    0.000000
# 17754     基期    0.000000
# 17755   基本一致    0.000000
# 17756   基本建设    0.000000
# ...

# %%
neg_pic = "img/thumbdown.jpg"
pos_pic = "img/thumbup.png"
neg_file = "img/thumbdown_neg.png"
pos_file = "img/thumbup_pos.png"
def color_func1(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Reds_9.colors[random.randint(2,8)])
def color_func2(word, font_size, position, orientation, random_state=None, **kwargs):
    return tuple(Greens_9.colors[random.randint(2,8)])
def maskwc(text,pic_file,down_file,col,color_func):
    mask = np.array(Image.open(pic_file))
    stopwords = set(STOPWORDS)

    with open('jieba_dict/stopwords.txt','r',encoding = 'utf-8') as sw:
        for line in sw:
            stopwords.add(line.strip('\n'))

    extra_stop = {"亿元","百分点","个百分点","评级","万元","YoY","我们认为","维持","1H17","同比","分别为","公司","营业","业务","项目"}
    stopwords = stopwords.union(extra_stop)
    seg_generator = jieba.cut(text)


    #wc = WordCloud(background_color="white", max_words=2000, mask=alice_mask,
               #stopwords=stopwords,
               #max_font_size=300, random_state=42)
    wc = WordCloud(font_path="simhei.ttf", background_color=col, max_words=4000, mask=mask,
               max_font_size=300, random_state=42,stopwords=stopwords)
    
    # generate word cloud
    wc.generate(text)
    wc.recolor(color_func=color_func, random_state=3)

# store to file
    wc.to_file(down_file)
    plt.imshow(wc, interpolation='bilinear')
    plt.axis("off")
    plt.figure()
    plt.show()
    text_list = text.split()

# %%
col = "white"
mask = color_func1
wc = WordCloud(font_path="simhei.ttf", background_color=col, max_words=4000, mask=mask,
               max_font_size=300, random_state=42)
    
    # generate word cloud
wc.generate(sort_imp)
wc.recolor(color_func=color_func, random_state=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-140-8ec8a9ec9b00> in <module>()
#       5
#       6     # generate word cloud
# ----> 7 wc.generate(sort_imp)
#       8 wc.recolor(color_func=color_func, random_state=3)
#
# ~/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     554         self
#     555         """
# --> 556         return self.generate_from_text(text)
#     557
#     558     def _check_generated(self):
#
# ~/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     539         self
#     540         """
# --> 541         words = self.process_text(text)
#     542         self.generate_from_frequencies(words)
#     543         return self
#
# ~/anaconda3/lib/python3.6/site-packages/wordcloud/wordcloud.py in process_text(self, text)
# ...

# %%
a = maskwc(textneg,neg_pic,neg_file,"white",color_func2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-9696911cd83a> in <module>()
# ----> 1 a = maskwc(textneg,neg_pic,neg_file,"white",color_func2)
#
# <ipython-input-122-1f39ec5eeeaf> in maskwc(text, pic_file, down_file, col, color_func)
#      28
#      29     # generate word cloud
# ---> 30     wc.generate_from_frequencies()
#      31     wc.recolor(color_func=color_func, random_state=3)
#      32
#
# TypeError: generate_from_frequencies() missing 1 required positional argument: 'frequencies'

# %%
wordcloud.WordCloud.generate_from_frequencies
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-da3d2271d7ca> in <module>()
# ----> 1 a.generate_from_frequencies()
#
# TypeError: generate_from_frequencies() missing 1 required positional argument: 'frequencies'

# %%
maskwc(textpos,pos_pic,pos_file,"white",color_func1)
